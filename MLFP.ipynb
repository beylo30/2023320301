# %% [markdown]
# # CIFAR-10: Best-Practice CNN + SVM Comparison + PCA Visualization
#
# This notebook keeps the **same main purpose** as your original code, but fixes dataset splitting, missing imports, and upgrades the model + training pipeline:
#
# - Train a strong **CNN with augmentation** on CIFAR-10
# - Evaluate on the **official test set**
# - Plot training curves, print classification report, and show confusion matrix
# - Train an **SVM baseline** (best practice: SVM on **CNN features**)
# - 3D **PCA visualization** (on CNN features)
# - Compare **original vs augmented** image
# - Predict on an **external image** (fixed preprocessing)

# %%
# !git config --global user.name "beylo30"
# !git config --global user.email "nabil.nours30@gmail.com"

# %%
# !git clone https://github.com/beylo30/2023320301

# %cd 2023320301
# Out:
# fatal: destination path '2023320301' already exists and is not an empty directory.
# /root/2023320301

# %%
# %cd /root/2023320301
# !ls
# !git status
# Out:
# /root/2023320301
#  data   imports  'load data'   README.md
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !find /content/drive/MyDrive -maxdepth 5 -name "*.ipynb"
# Out:
# /content/drive/MyDrive/MLFP.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled0.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled1.ipynb
# /content/drive/MyDrive/Colab Notebooks/Question 3.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled2.ipynb
# /content/drive/MyDrive/Colab Notebooks/study.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled3.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled4.ipynb
# /content/drive/MyDrive/Colab Notebooks/lotto.ipynb
# /content/drive/MyDrive/Colab Notebooks/2022 spring.ipynb
# /content/drive/MyDrive/Colab Notebooks/2022 Fall.ipynb
# /content/drive/MyDrive/Colab Notebooks/2022 summer.ipynb
# /content/drive/MyDrive/Colab Notebooks/2023.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled6.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled5.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled7.ipynb
# /content/drive/MyDrive/Colab Notebooks/Midterm.ipynb
# /content/drive/MyDrive/Colab Notebooks/Q3.ipynb
# /content/drive/MyDrive/Colab Notebooks/Q2 (1).ipynb
# /content/drive/MyDrive/Colab Notebooks/Mid Programming 2.ipynb
# /content/drive/MyDrive/Colab Notebooks/Q1.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled8.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled9.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled10.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled11.ipynb
# /content/drive/MyDrive/Colab Notebooks/Q2.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled12.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled13.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled14.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled15.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled16.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled17.ipynb
# /content/drive/MyDrive/Colab Notebooks/For data_jawi_lmdb.ipynb
# /content/drive/MyDrive/Colab Notebooks/ML Final Project.ipynb
# /content/drive/MyDrive/Colab Notebooks/Copy of ML Final Project.ipynb
# /content/drive/MyDrive/assignment_release/P1d.introduction-TF-IDF.ipynb
# /content/drive/MyDrive/assignment_release/P1a.data-exploration.ipynb
# /content/drive/MyDrive/assignment_release/P2d.fine-tuning-BERT (reference).ipynb
# /content/drive/MyDrive/assignment_release/P2b.train-with-BERT-embedding.ipynb
# /content/drive/MyDrive/assignment_release/P2a.guide-to-using-BERT.ipynb
# /content/drive/MyDrive/assignment_release/P2c.train-with-BERT-embedding-limited-label.ipynb
# /content/drive/MyDrive/assignment2/P2b.train-with-BERT-embedding.ipynb
# /content/drive/MyDrive/assignment2/P2d.fine-tuning-BERT (reference).ipynb
# /content/drive/MyDrive/assignment2/P2a.guide-to-using-BERT.ipynb
# /content/drive/MyDrive/assignment2/P2c.train-with-BERT-embedding-limited-label.ipynb
# /content/drive/MyDrive/assignment3_release/P3c.ESCI-fine-tuning-BERT (reference).ipynb
# /content/drive/MyDrive/assignment3_release/P3b.ESCI-train-with-BERT-embedding.ipynb
# /content/drive/MyDrive/assignment3_release/P3a.train-with-BERT-embedding-no-label.ipynb
# /content/drive/MyDrive/assignment3/P3c.ESCI-fine-tuning-BERT (reference).ipynb
# /content/drive/MyDrive/assignment3/P3b.ESCI-train-with-BERT-embedding.ipynb
# /content/drive/MyDrive/assignment3/P3a.train-with-BERT-embedding-no-label.ipynb
# /content/drive/MyDrive/assignment4/P5a.intro-to-GNN.ipynb
# /content/drive/MyDrive/assignment4/P5b.category-classification-with-GNN.ipynb
# /content/drive/MyDrive/MLFinalProject/ML Final Project.ipynb

# %%
# %cd /content

# !cp "/content/drive/MyDrive/MLFP.ipynb" .
# Out:
# /content

# %%
# %cd /content

# !git add .
# !git commit -m "Add files"
# !git push
# Out:
# /content
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
# Imports + Reproducibility
import os
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers

from tensorflow.keras.datasets import cifar10

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.decomposition import PCA

# Optional (nice 3D plot). If not available, we'll fallback to matplotlib 3D.
try:
    import plotly.express as px
    PLOTLY_AVAILABLE = True
except Exception:
    PLOTLY_AVAILABLE = False

# Reproducibility (best effort)
tf.keras.utils.set_random_seed(42)
np.random.seed(42)

print("TensorFlow:", tf.__version__)
print("GPU available:", len(tf.config.list_physical_devices('GPU')) > 0)
# Out:
# TensorFlow: 2.19.0
# GPU available: True

# %%
# =========================
# Load CIFAR-10 properly
# =========================
(X_train_full, y_train_full), (X_test, y_test) = cifar10.load_data()

classes = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck']
num_classes = 10

y_train_full = y_train_full.reshape(-1,)
y_test = y_test.reshape(-1,)

print("\nOfficial CIFAR-10 split:")
print("Train:", X_train_full.shape, y_train_full.shape)
print("Test :", X_test.shape, y_test.shape)

# Create a VALIDATION set from the official training set
X_train, X_val, y_train, y_val = train_test_split(
    X_train_full, y_train_full,
    test_size=0.2,
    random_state=42,
    stratify=y_train_full
)

# Normalize
X_train = X_train.astype("float32") / 255.0
X_val   = X_val.astype("float32") / 255.0
X_test  = X_test.astype("float32") / 255.0

print("\nAfter train/val split:")
print("Train:", X_train.shape, y_train.shape)
print("Val  :", X_val.shape, y_val.shape)
print("Test :", X_test.shape, y_test.shape)

# =========================
# Utility: plot sample
# =========================
def plot_sample(X, y, index):
    plt.figure(figsize=(3,3))
    plt.imshow(X[index])
    plt.title(classes[int(y[index])])
    plt.axis('off')
    plt.show()

plot_sample(X_train, y_train, 56)
# Out:
# Official CIFAR-10 split:
# Train: (50000, 32, 32, 3) (50000,)
# Test : (10000, 32, 32, 3) (10000,)
#
# After train/val split:
# Train: (40000, 32, 32, 3) (40000,)
# Val  : (10000, 32, 32, 3) (10000,)
# Test : (10000, 32, 32, 3) (10000,)

# %%
# =========================
# tf.data pipelines (fast)
# =========================
BATCH_SIZE = 128
AUTOTUNE = tf.data.AUTOTUNE

train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train_ds = train_ds.shuffle(20000, seed=42, reshuffle_each_iteration=True).batch(BATCH_SIZE).prefetch(AUTOTUNE)

val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)).batch(BATCH_SIZE).prefetch(AUTOTUNE)
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(BATCH_SIZE).prefetch(AUTOTUNE)

# =========================
# Data Augmentation (inside model)
# =========================
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomTranslation(0.1, 0.1),
        layers.RandomRotation(0.05),
        layers.RandomZoom(0.1),
    ],
    name="data_augmentation"
)

# %%
# =========================
# Better CNN: small ResNet-style (strong for CIFAR-10)
# =========================
weight_decay = 1e-4
l2 = regularizers.l2(weight_decay)

def conv_bn_lrelu(x, filters, k=3, s=1):
    x = layers.Conv2D(filters, k, strides=s, padding="same",
                      use_bias=False, kernel_regularizer=l2)(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU(0.1)(x)
    return x

def residual_block(x, filters, downsample=False):
    stride = 2 if downsample else 1
    shortcut = x

    x = conv_bn_lrelu(x, filters, k=3, s=stride)
    x = layers.Conv2D(filters, 3, strides=1, padding="same",
                      use_bias=False, kernel_regularizer=l2)(x)
    x = layers.BatchNormalization()(x)

    # Match dimensions for residual add
    if downsample or shortcut.shape[-1] != filters:
        shortcut = layers.Conv2D(filters, 1, strides=stride, padding="same",
                                 use_bias=False, kernel_regularizer=l2)(shortcut)
        shortcut = layers.BatchNormalization()(shortcut)

    x = layers.Add()([x, shortcut])
    x = layers.LeakyReLU(0.1)(x)
    return x

inputs = keras.Input(shape=(32, 32, 3))
x = data_augmentation(inputs)

# Stem
x = conv_bn_lrelu(x, 32)
x = conv_bn_lrelu(x, 32)

# Stages
x = residual_block(x, 32)
x = residual_block(x, 32)

x = residual_block(x, 64, downsample=True)
x = residual_block(x, 64)

x = residual_block(x, 128, downsample=True)
x = residual_block(x, 128)

x = residual_block(x, 256, downsample=True)
x = residual_block(x, 256)

x = layers.GlobalAveragePooling2D(name="features")(x)
x = layers.Dropout(0.3)(x)
logits = layers.Dense(num_classes, name="logits")(x)

model = keras.Model(inputs, logits, name="CIFAR10_ResNetSmall")

# Optimizer (AdamW if available, else Adam)
try:
    optimizer = keras.optimizers.AdamW(learning_rate=1e-3, weight_decay=weight_decay)
except Exception:
    optimizer = keras.optimizers.Adam(learning_rate=1e-3)

model.compile(
    optimizer=optimizer,
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=["accuracy"]
)

model.summary()
# Out:
# Model: "CIFAR10_ResNetSmall"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 32, 32, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ data_augmentation   │ (None, 32, 32, 3) │          0 │ input_layer[0][0] │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 32, 32,    │        864 │ data_augmentatio… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 32, 32,    │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu         │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 32, 32,    │      9,216 │ leaky_re_lu[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        128 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_1       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 32, 32,    │      9,216 │ leaky_re_lu_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        128 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_2       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 32, 32,    │      9,216 │ leaky_re_lu_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        128 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ leaky_re_lu_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_3       │ (None, 32, 32,    │          0 │ add[0][0]         │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 32,    │      9,216 │ leaky_re_lu_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        128 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_4       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │      9,216 │ leaky_re_lu_4[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        128 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ leaky_re_lu_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_5       │ (None, 32, 32,    │          0 │ add_1[0][0]       │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 16, 16,    │     18,432 │ leaky_re_lu_5[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_6       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 16, 16,    │     36,864 │ leaky_re_lu_6[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │      2,048 │ leaky_re_lu_5[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_7       │ (None, 16, 16,    │          0 │ add_2[0][0]       │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │     36,864 │ leaky_re_lu_7[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_8       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 16, 16,    │     36,864 │ leaky_re_lu_8[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ leaky_re_lu_7[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_9       │ (None, 16, 16,    │          0 │ add_3[0][0]       │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 8, 8, 128) │     73,728 │ leaky_re_lu_9[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 128) │        512 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_10      │ (None, 8, 8, 128) │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 8, 8, 128) │    147,456 │ leaky_re_lu_10[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 8, 8, 128) │      8,192 │ leaky_re_lu_9[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 128) │        512 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 128) │        512 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 8, 8, 128) │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_11      │ (None, 8, 8, 128) │          0 │ add_4[0][0]       │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 8, 8, 128) │    147,456 │ leaky_re_lu_11[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 128) │        512 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_12      │ (None, 8, 8, 128) │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 8, 8, 128) │    147,456 │ leaky_re_lu_12[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 128) │        512 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 8, 8, 128) │          0 │ batch_normalizat… │
# │                     │                   │            │ leaky_re_lu_11[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_13      │ (None, 8, 8, 128) │          0 │ add_5[0][0]       │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 4, 4, 256) │    294,912 │ leaky_re_lu_13[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 256) │      1,024 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_14      │ (None, 4, 4, 256) │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 4, 4, 256) │    589,824 │ leaky_re_lu_14[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 4, 4, 256) │     32,768 │ leaky_re_lu_13[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 256) │      1,024 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 256) │      1,024 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 4, 4, 256) │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_15      │ (None, 4, 4, 256) │          0 │ add_6[0][0]       │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 4, 4, 256) │    589,824 │ leaky_re_lu_15[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 256) │      1,024 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_16      │ (None, 4, 4, 256) │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 4, 4, 256) │    589,824 │ leaky_re_lu_16[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 256) │      1,024 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 4, 4, 256) │          0 │ batch_normalizat… │
# │                     │                   │            │ leaky_re_lu_15[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_17      │ (None, 4, 4, 256) │          0 │ add_7[0][0]       │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ features            │ (None, 256)       │          0 │ leaky_re_lu_17[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ features[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ logits (Dense)      │ (None, 10)        │      2,570 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,811,754 (10.73 MB)
#  Trainable params: 2,806,890 (10.71 MB)
#  Non-trainable params: 4,864 (19.00 KB)

# %%
# =========================
# Callbacks (make training "best")
# =========================
callbacks = [
    keras.callbacks.ModelCheckpoint("best_cifar10_model.keras", monitor="val_accuracy",
                                    save_best_only=True, verbose=1),
    keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=3, min_lr=1e-6, verbose=1),
    keras.callbacks.EarlyStopping(monitor="val_accuracy", patience=10, restore_best_weights=True, verbose=1),
]

EPOCHS = 10  # EarlyStopping will likely stop earlier if it converges

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks
)
# Out:
# Epoch 1/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.3492 - loss: 2.1048
# Epoch 1: val_accuracy improved from -inf to 0.35130, saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 46s 94ms/step - accuracy: 0.3494 - loss: 2.1040 - val_accuracy: 0.3513 - val_loss: 2.2834 - learning_rate: 0.0010
# Epoch 2/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.5462 - loss: 1.4812
# Epoch 2: val_accuracy did not improve from 0.35130
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 29s 91ms/step - accuracy: 0.5462 - loss: 1.4810 - val_accuracy: 0.3488 - val_loss: 2.9154 - learning_rate: 0.0010
# Epoch 3/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6329 - loss: 1.2563
# Epoch 3: val_accuracy improved from 0.35130 to 0.62020, saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 28s 89ms/step - accuracy: 0.6329 - loss: 1.2562 - val_accuracy: 0.6202 - val_loss: 1.3657 - learning_rate: 0.0010
# Epoch 4/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6808 - loss: 1.1230
# Epoch 4: val_accuracy improved from 0.62020 to 0.63430, saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 28s 90ms/step - accuracy: 0.6808 - loss: 1.1229 - val_accuracy: 0.6343 - val_loss: 1.3233 - learning_rate: 0.0010
# Epoch 5/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7113 - loss: 1.0382
# Epoch 5: val_accuracy improved from 0.63430 to 0.66110, saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 29s 92ms/step - accuracy: 0.7113 - loss: 1.0382 - val_accuracy: 0.6611 - val_loss: 1.2538 - learning_rate: 0.0010
# Epoch 6/10
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7294 - loss: 0.9810
# Epoch 6: val_accuracy improved from 0.66110 to 0.66310, saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 28s 89ms/step - accuracy: 0.7295 - loss: 0.9809 - val_accuracy: 0.6631 - val_loss: 1.2233 - learning_rate: 0.0010
# Epoch 7/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7467 - loss: 0.9308
# Epoch 7: val_accuracy improved from 0.66310 to 0.71560, saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 28s 90ms/step - accuracy: 0.7467 - loss: 0.9307 - val_accuracy: 0.7156 - val_loss: 1.1009 - learning_rate: 0.0010
# Epoch 8/10
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7628 - loss: 0.8880
# Epoch 8: val_accuracy improved from 0.71560 to 0.74470, saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 28s 89ms/step - accuracy: 0.7628 - loss: 0.8880 - val_accuracy: 0.7447 - val_loss: 0.9486 - learning_rate: 0.0010
# Epoch 9/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7735 - loss: 0.8631
# Epoch 9: val_accuracy did not improve from 0.74470
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 28s 88ms/step - accuracy: 0.7735 - loss: 0.8631 - val_accuracy: 0.7143 - val_loss: 1.1230 - learning_rate: 0.0010
# Epoch 10/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7796 - loss: 0.8465
# Epoch 10: val_accuracy did not improve from 0.74470
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 28s 88ms/step - accuracy: 0.7796 - loss: 0.8465 - val_accuracy: 0.7043 - val_loss: 1.1510 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 8.

# %%
# =========================
# Evaluate on official TEST set
# =========================
test_loss, test_acc = model.evaluate(test_ds, verbose=0)
print("\nOfficial TEST accuracy:", test_acc)

# =========================
# Training curves (train + val)
# =========================
hist = history.history
epochs_r = range(1, len(hist["accuracy"]) + 1)

plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
plt.plot(epochs_r, hist["accuracy"], label="Train Acc")
plt.plot(epochs_r, hist["val_accuracy"], label="Val Acc")
plt.title("Accuracy")
plt.legend()

plt.subplot(1,2,2)
plt.plot(epochs_r, hist["loss"], label="Train Loss")
plt.plot(epochs_r, hist["val_loss"], label="Val Loss")
plt.title("Loss")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Official TEST accuracy: 0.7376000285148621

# %%
# =========================
# Classification report + confusion matrix (TEST)
# =========================
y_pred_logits = model.predict(test_ds, verbose=0)
y_pred = np.argmax(y_pred_logits, axis=1)

print("\nClassification Report (TEST):")
print(classification_report(y_test, y_pred, target_names=classes))

cm = confusion_matrix(y_test, y_pred)

def plot_confusion_matrix(cm, class_names):
    plt.figure(figsize=(8,6))
    plt.imshow(cm)
    plt.title("Confusion Matrix (TEST)")
    plt.colorbar()
    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names, rotation=45, ha="right")
    plt.yticks(tick_marks, class_names)

    thresh = cm.max() * 0.6
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, cm[i, j],
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black",
                     fontsize=8)

    plt.ylabel("True label")
    plt.xlabel("Predicted label")
    plt.tight_layout()
    plt.show()

plot_confusion_matrix(cm, classes)
# Out:
# Classification Report (TEST):
#               precision    recall  f1-score   support
#
#     Airplane       0.68      0.82      0.75      1000
#   Automobile       0.99      0.71      0.83      1000
#         Bird       0.65      0.66      0.66      1000
#          Cat       0.54      0.67      0.60      1000
#         Deer       0.81      0.66      0.72      1000
#          Dog       0.67      0.65      0.66      1000
#         Frog       0.72      0.84      0.77      1000
#        Horse       0.85      0.74      0.79      1000
#         Ship       0.96      0.69      0.81      1000
#        Truck       0.74      0.92      0.82      1000
#
#     accuracy                           0.74     10000
#    macro avg       0.76      0.74      0.74     10000
# weighted avg       0.76      0.74      0.74     10000

# %%
# =========================
# SVM baseline (BEST way): SVM on CNN features
# =========================
feature_extractor = keras.Model(model.input, model.get_layer("features").output)

# Extract features in batches for speed
train_features = feature_extractor.predict(train_ds, verbose=0)
val_features   = feature_extractor.predict(val_ds, verbose=0)
test_features  = feature_extractor.predict(test_ds, verbose=0)

# Train SVM on (train + val) features for a fair final comparison
X_svm_train = np.concatenate([train_features, val_features], axis=0)
y_svm_train = np.concatenate([y_train, y_val], axis=0)

svm_pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("svm", LinearSVC(dual=False, max_iter=5000))
])

param_grid = {
    "svm__C": [0.1, 1, 3, 10]
}

grid = GridSearchCV(svm_pipe, param_grid, cv=3, n_jobs=-1, verbose=1)
grid.fit(X_svm_train, y_svm_train)

print("\nBest SVM params:", grid.best_params_)
svm_best = grid.best_estimator_
svm_test_acc = svm_best.score(test_features, y_test)
print("SVM TEST accuracy (on CNN features):", svm_test_acc)
# Out:
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
#
# Best SVM params: {'svm__C': 0.1}
# SVM TEST accuracy (on CNN features): 0.7647

# %%
# =========================
# 3D Visualization (PCA on CNN features)
# =========================
# Use a subset so plotting is fast
N = 6000
idx = np.random.RandomState(42).choice(len(X_svm_train), size=min(N, len(X_svm_train)), replace=False)
feat_subset = X_svm_train[idx]
y_subset = y_svm_train[idx]

pca = PCA(n_components=3, random_state=42)
feat_3d = pca.fit_transform(feat_subset)

if PLOTLY_AVAILABLE:
    fig = px.scatter_3d(
        x=feat_3d[:,0], y=feat_3d[:,1], z=feat_3d[:,2],
        color=y_subset.astype(str),
        title="3D PCA of CNN Features (CIFAR-10)",
        labels={"color": "Class"}
    )
    fig.show()
else:
    from mpl_toolkits.mplot3d import Axes3D  # noqa: F401
    fig = plt.figure(figsize=(8,6))
    ax = fig.add_subplot(111, projection="3d")
    ax.scatter(feat_3d[:,0], feat_3d[:,1], feat_3d[:,2], c=y_subset, s=5)
    ax.set_title("3D PCA of CNN Features (CIFAR-10)")
    plt.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a1514537-87ef-413d-8a6c-57e4b94ad379" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a1514537-87ef-413d-8a6c-57e4b94ad379")) {                    Plotly.newPlot(                        "a1514537-87ef-413d-8a6c-57e4b94ad379",                        [{"hovertemplate":"Class=3\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ez=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"3","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"3","scene":"scene","showlegend":true,"x":[1.4780087,-4.437711,-3.696005,-3.359875,-4.651021,-6.2333555,-2.7717447,-2.384914,-3.1902494,-2.4278371,0.45309377,-2.2718797,-4.6723304,2.9876933,-4.7504234,10.213457,15.488419,-2.6837313,0.15437508,-4.477174,-4.1422653,0.2775879,-1.7505467,-4.0051556,4.9495225,-6.496792,6.659784,-4.356407,-3.912701,-4.6878123,-4.2539577,-4.781332,0.36173368,5.9676576,-3.9610445,-2.103359,-3.2946327,2.0703201,-2.1213465,-2.2135954,-4.0081215,-3.3348267,-6.525193,9.927523,-3.2498167,-5.8187075,-4.6146226,0.8900647,11.343765,-2.307836,-3.0824187,-4.010784,1.4799385,9.34301,3.1907206,10.589348,1.3042951,5.9271026,0.8368912,-4.742262,1.1458693,-5.040941,6.42594,-1.5783414,-2.4633303,-1.6444625,-2.7643952,-0.8716068,-3.9433088,-0.040284634,-4.809958,-6.189142,-3.5454264,6.8250804,1.6305571,4.1510377,-5.148466,-4.9319234,-2.6688004,-3.122649,-1.8169541,0.28780603,-1.0667334,-0.9871962,-6.1702676,-1.333207,-4.4519396,-4.701852,-4.493863,8.402208,-0.056548357,-1.0708303,-5.6632004,0.10371733,-2.005167,4.660667,6.8301187,-2.1252065,-1.8750502,7.9595933,-5.920414,-5.6882114,-5.117395,-3.9543324,-3.3129683,-2.0471072,8.404057,-5.004442,3.243414,0.77756476,-1.2989324,-0.99343634,-1.1393356,-2.0949972,-3.9871843,14.056147,9.115082,-5.701535,-5.667497,1.869545,-5.1780114,15.719706,2.4017363,-1.9966971,-0.8632071,9.401907,-4.8618007,-2.5089123,6.343227,-3.7129662,-5.777095,12.772125,-1.101578,-2.0581565,0.12062144,-0.7671952,-4.2231493,-1.0247765,-1.6059247,-4.7600584,-5.9740057,-3.1722329,-5.0328374,-4.9086366,6.1210456,-6.416768,-1.513615,-4.025952,-1.6569489,-4.546576,3.4158802,-2.5442538,-0.22693872,1.0352788,-4.3429484,6.9549127,-2.4110143,-5.5570765,-2.2029965,5.8622146,-5.5937767,-3.0693634,-5.9636106,-6.1504936,5.7004294,4.2674747,-5.8164845,-6.0710864,-5.104417,-3.0600088,-4.0302405,-5.388171,-6.3502173,-3.1209548,0.5226145,3.42871,-0.5954056,-1.2859955,0.35066414,6.303064,3.0012078,3.1134024,-0.3797555,-1.1109864,-2.9004774,7.7167125,-2.3258314,5.2355027,0.20348811,-3.0610518,-2.4975903,13.439568,-0.04309368,-4.4284797,-3.2360668,10.209335,-5.370823,-5.238966,2.040441,-0.95669484,-1.7743666,5.0825715,0.76626897,-4.345122,2.4523125,-2.7668693,-2.6156936,-2.4613564,4.023848,-5.379716,-2.1327856,-1.1112812,1.1390629,-2.124142,1.1699195,10.0569935,0.8754976,-2.2060215,0.093919754,-1.3317856,-2.936763,13.36278,-1.5428128,-5.0332174,-1.610886,13.4625435,-0.31745124,-3.8657584,-1.6487612,-3.8321462,-2.391777,12.270807,-3.5626268,-1.5245169,-3.116955,-3.638616,-3.6410553,-4.9763417,0.39836407,-2.4931216,-0.14625001,-1.7593439,-4.60332,-4.185732,-3.7143521,-5.922041,-2.375288,-4.923375,-1.498581,-4.6637526,-4.507417,-3.698762,-5.1860137,-5.224751,-3.3213255,13.108585,-4.6390333,-2.5968015,11.828951,-0.19166541,-2.34166,18.705635,-3.810122,-4.545251,-2.8803713,10.509491,-3.8841066,-0.3138225,13.343857,-7.265618,-2.758716,13.128569,-6.5940123,-0.19559693,-4.7711654,-1.6042364,-2.2328267,-3.4547818,-4.203747,-3.667102,-1.0566802,-2.0660665,-2.925421,-4.989901,0.40405583,1.7023091,-7.317188,12.876919,-1.1370983,-6.80367,-2.7288582,-5.8297977,1.3083148,0.50792646,6.95717,-4.8187814,10.391151,-3.1634874,-2.7618895,-6.378007,-5.238587,-1.1068041,-1.1330891 ...

# %%
# =========================
# Compare original vs augmented image
# =========================
index = 56
original_image = X_train[index]
augmented_image = data_augmentation(tf.expand_dims(original_image, 0), training=True)[0].numpy()

plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
plt.imshow(original_image)
plt.title("Original")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(augmented_image)
plt.title("Augmented")
plt.axis("off")

plt.tight_layout()
plt.show()

# %%
# =========================
# Predict on external image (fixed preprocessing)
# =========================
random_url = "https://www.lamborghini.com/sites/it-en/files/DAM/lamborghini/facelift_2019/homepage/families-gallery/2023/revuelto/revuelto_m.png"

local_path = tf.keras.utils.get_file("external_img.png", origin=random_url)
img = keras.utils.load_img(local_path, target_size=(32, 32))
img_array = keras.utils.img_to_array(img).astype("float32") / 255.0
img_array = tf.expand_dims(img_array, 0)

pred = model.predict(img_array, verbose=0)
probs = tf.nn.softmax(pred[0]).numpy()

top = np.argmax(probs)
print(f"\nExternal image prediction: {classes[top]} ({probs[top]*100:.2f}%)")

plt.figure(figsize=(3,3))
plt.imshow(img)
plt.title(f"Pred: {classes[top]} ({probs[top]*100:.1f}%)")
plt.axis("off")
plt.show()
# Out:
# Downloading data from https://www.lamborghini.com/sites/it-en/files/DAM/lamborghini/facelift_2019/homepage/families-gallery/2023/revuelto/revuelto_m.png
# 320962/320962 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
#
# External image prediction: Automobile (65.84%)
